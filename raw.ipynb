# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/shivangsingh/Downloads/202412 - JPM.csv')
df
# Out:
# /var/folders/xh/jp0rh_x11gxdpdfdn0550hnc0000gp/T/ipykernel_7035/4058140741.py:1: DtypeWarning: Columns (88,89,95,96,97,98,110,111,135,138,141,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/shivangsingh/Downloads/202412 - JPM.csv')
#        Unnamed: 0  AgreementRef StartDate PurchaseDate         LOB  \
# 0        202104.0    1300382496  19/04/21     28/02/22       Prime
# 1        202104.0    1300382777  19/04/21     28/02/22       Prime
# 2        202104.0    1300383042  20/04/21     28/02/22       Prime
# 3        202104.0    1300383411  22/04/21     28/02/22       Prime
# 4        202105.0    1300386057  04/05/21     28/02/22       Prime
# ...           ...           ...       ...          ...         ...
# 44196         NaN    1300722121     45653        45656  Near Prime
# 44197         NaN    1300722318     45655        45658  Near Prime
# 44198         NaN    1300722766     45657        45660  Near Prime
# ...
